# %%
import tensorflow as tf
from keras.datasets.mnist import load_data
import numpy as np

(x_train, y_train), (x_test, y_test) = load_data()
x_train = ((x_train/255 - 0.5) * 2).astype(np.float32).reshape(x_train.shape[0], -1)
x_test = ((x_test/255 - 0.5) * 2).astype(np.float32).reshape(x_test.shape[0], -1)

print(f"{x_train.shape=}")
print(f"{y_train.shape=}")
print(f"{x_test.shape=}")
print(f"{y_test.shape=}")
# Out:
# x_train.shape=(60000, 784)
# y_train.shape=(60000,)
# x_test.shape=(10000, 784)
# y_test.shape=(10000,)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows = 2, ncols=5)
ax = ax.flatten()

for i in range(10):
  img = x_train[y_train == i][0].reshape(28,28)
  ax[i].imshow(img, cmap="Greys")
  ax[i].axis('off')
plt.tight_layout()
plt.show()

# %%
import numpy.typing as npt

class NeuralNetMLP:
  w_h: npt.NDArray 
  b_h: npt.NDArray
  w_out: npt.NDArray
  b_out: npt.NDArray
  def __init__(self, n_hidden=30, l2=0, epochs=100, eta=0.001, shuffle=True, minibatch_size = 1, seed=None):
    self.random = np.random.RandomState(seed)
    self.n_hidden = n_hidden
    self.l2 = l2
    self.epochs = epochs
    self.eta = eta
    self.shuffle = shuffle
    self.minibatch_size = minibatch_size

  def _onehot(self, y, n_classes):
    one_hot = np.zeros((y.shape[0], n_classes))
    one_hot[np.arange(y.shape[0]), y] = 1
    return one_hot
  def _sigmoid(self, z):
    return 1./ (1. + np.exp(-np.clip(z, -250., 250.)))

  def _forward(self, X):
    # (n_s, n_features) dot (n_features, n_hidden) -> (n_s, n_hidden)  
    z_h = np.dot(X, self.w_h) + self.b_h
    a_h = self._sigmoid(z_h)
    # (n_s, n_hidden) dot (n_hidden, n_classes) -> (n_s, n_classes) 
    z_out = np.dot(a_h, self.w_out) + self.b_out
    a_out = self._sigmoid(z_out)
    return z_h, a_h, z_out, a_out

  def _compute_loss(self, y_enc, output):
    L2_term = (np.sum(self.w_h * self.w_h) + np.sum(self.w_out * self.w_out)) * self.l2
    term1 = -y_enc * np.log(output)
    term2 = (1. - y_enc) * np.log(1. - output)
    cost = np.sum(term1 - term2) / y_enc.shape[0] + L2_term
    return cost

  def predict(self, X):
    z_h, a_h, z_out, a_out = self._forward(X)
    y_pred = np.argmax(a_out, axis=1)
    return y_pred

  def fit(self, x_train, y_train, x_valid, y_valid):
    n_output = np.unique(y_train).shape[0]  
    n_features = x_train.shape[1]
    

    self.w_h = self.random.normal(loc=0., scale=1.0, size=(n_features, self.n_hidden))
    self.b_h = np.zeros(self.n_hidden)

    self.w_out = self.random.normal(loc=0., scale=1.0, size=(self.n_hidden, n_output))
    self.b_out = np.zeros(n_output)

    epoch_strlen = len(str(self.epochs))
    self.eval_ = {'cost': [], 'train_acc': [], 'valid_acc': []}

    y_train_enc = self._onehot(y_train, n_output)

    for i in range(self.epochs):

      indices = np.arange(x_train.shape[0])
      
      if self.shuffle:
        self.random.shuffle(indices)

      for start_idx in range(0, x_train.shape[0], self.minibatch_size):
        batch_idx = indices[start_idx: start_idx + self.minibatch_size]  

        z_h, a_h, z_out, a_out = self._forward(x_train[batch_idx])

        # (n_sample, n_classes) 
        sigma_out = a_out - y_train_enc[batch_idx]
        # (n_sample, n_hidden)
        sigmoid_derivative_h = (a_h) * (1. - a_h)
        # (n_sample, n_classes) dot (n_classes, n_hidden) -> (n_sample, n_hidden)
        sigma_h = np.dot(sigma_out, self.w_out.T) * sigmoid_derivative_h

        # (n_features, n_sample) dot (n_sample, n_hidden) -> (n_features, n_hidden)
        grad_w_h = np.dot(x_train[batch_idx].T, sigma_h)
        grad_b_h = np.sum(sigma_h, axis=0)

        # (n_hidden, n_sample) dot (n_sample, n_classes) -> (n_hidden, n_classes)
        grad_w_out = np.dot(a_h.T, sigma_out)
        grad_b_out = np.sum(sigma_out, axis=0)

        delta_w_h = grad_w_h + self.l2 * self.w_h
        delta_b_h = grad_b_h
        self.w_h -= self.eta * delta_w_h
        self.b_h -= self.eta * delta_b_h

        delta_w_out = grad_w_out + self.l2 * self.w_out
        delta_b_out = grad_b_out
        self.w_out -= self.eta * delta_w_out
        self.b_out -= self.eta * delta_b_out

      z_h, a_h, z_out, a_out = self._forward(x_train)
      cost = self._compute_loss(y_train_enc, a_out)

      y_train_pred = self.predict(x_train)
      y_valid_pred = self.predict(x_valid)

      train_acc = np.sum(y_train == y_train_pred).astype(np.float32) / x_train.shape[0]
      valid_acc = np.sum(y_valid == y_valid_pred).astype(np.float32) / x_valid.shape[0]

      print(f"epoch: {i:0{epoch_strlen}d} | Cost: {cost:.3f} | Train/Valid Acc: {train_acc:.4f}/{valid_acc:.4f}")

      self.eval_['cost'].append(cost)
      self.eval_['train_acc'].append(train_acc)
      self.eval_['valid_acc'].append(valid_acc)
    return self   
  def save_weights(self):
    np.savez_compressed(f"weight-{self.epochs}-{self.eval_['cost'][-1]:.3f}-{self.eval_['train_acc'][-1]:.4f}-{self.eval_['valid_acc'][-1]:.4f}", w_h=self.w_h, b_h=self.b_h, w_out=self.w_out, b_out=self.b_out)
  
  def load_weights(self, filename):
    weights = np.load(filename)

    self.w_h = weights['w_h']
    self.b_h = weights['b_h']
    self.w_out = weights['w_out']
    self.b_out = weights['b_out']

# %%
nn = NeuralNetMLP(n_hidden=500, epochs=200, l2=0.05,eta=0.001, minibatch_size=100, shuffle=True, seed=0)
print(f"{x_train[:55000].shape=}")
print(f"{y_train[:55000].shape=}")
print(f"{x_train[55000:].shape=}")
print(f"{y_train[55000:].shape=}")
nn.fit(x_train=x_train[:55000], y_train=y_train[:55000], x_valid=x_train[55000:], y_valid=y_train[55000:])
# Out:
# x_train[:55000].shape=(55000, 784)
# y_train[:55000].shape=(55000,)
# x_train[55000:].shape=(5000, 784)
# y_train[55000:].shape=(5000,)
# epoch: 000 | Cost: 18724.403 | Train/Valid Acc: 0.8073/0.8362
# epoch: 001 | Cost: 17716.135 | Train/Valid Acc: 0.8556/0.8782
# epoch: 002 | Cost: 16763.863 | Train/Valid Acc: 0.8777/0.8970
# epoch: 003 | Cost: 15863.648 | Train/Valid Acc: 0.8919/0.9076
# epoch: 004 | Cost: 15012.340 | Train/Valid Acc: 0.9033/0.9158
# epoch: 005 | Cost: 14207.140 | Train/Valid Acc: 0.9106/0.9234
# epoch: 006 | Cost: 13445.449 | Train/Valid Acc: 0.9177/0.9264
# epoch: 007 | Cost: 12724.865 | Train/Valid Acc: 0.9230/0.9304
# epoch: 008 | Cost: 12043.118 | Train/Valid Acc: 0.9287/0.9352
# epoch: 009 | Cost: 11398.101 | Train/Valid Acc: 0.9332/0.9376
# epoch: 010 | Cost: 10787.796 | Train/Valid Acc: 0.9357/0.9404
# epoch: 011 | Cost: 10210.315 | Train/Valid Acc: 0.9410/0.9416
# epoch: 012 | Cost: 9663.897 | Train/Valid Acc: 0.9429/0.9436
# epoch: 013 | Cost: 9146.853 | Train/Valid Acc: 0.9448/0.9436
# epoch: 014 | Cost: 8657.585 | Train/Valid Acc: 0.9481/0.9460
# epoch: 015 | Cost: 8194.604 | Train/Valid Acc: 0.9499/0.9490
# epoch: 016 | Cost: 7756.491 | Train/Valid Acc: 0.9522/0.9488
# epoch: 017 | Cost: 7341.906 | Train/Valid Acc: 0.9531/0.9492
# epoch: 018 | Cost: 6949.574 | Train/Valid Acc: 0.9555/0.9522
# epoch: 019 | Cost: 6578.314 | Train/Valid Acc: 0.9563/0.9540
# epoch: 020 | Cost: 6226.972 | Train/Valid Acc: 0.9586/0.9564
# epoch: 021 | Cost: 5894.496 | Train/Valid Acc: 0.9594/0.9560
# epoch: 022 | Cost: 5579.857 | Train/Valid Acc: 0.9611/0.9558
# epoch: 023 | Cost: 5282.109 | Train/Valid Acc: 0.9611/0.9568
# epoch: 024 | Cost: 5000.330 | Train/Valid Acc: 0.9621/0.9596
# epoch: 025 | Cost: 4733.665 | Train/Valid Acc: 0.9633/0.9592
# epoch: 026 | Cost: 4481.316 | Train/Valid Acc: 0.9637/0.9584
# epoch: 027 | Cost: 4242.491 | Train/Valid Acc: 0.9659/0.9616
# epoch: 028 | Cost: 4016.481 | Train/Valid Acc: 0.9670/0.9618
# epoch: 029 | Cost: 3802.604 | Train/Valid Acc: 0.9676/0.9620
# epoch: 030 | Cost: 3600.209 | Train/Valid Acc: 0.9685/0.9624
# epoch: 031 | Cost: 3408.664 | Train/Valid Acc: 0.9689/0.9650
# epoch: 032 | Cost: 3227.396 | Train/Valid Acc: 0.9687/0.9634
# epoch: 033 | Cost: 3055.851 | Train/Valid Acc: 0.9705/0.9654
# epoch: 034 | Cost: 2893.507 | Train/Valid Acc: 0.9711/0.9664
# epoch: 035 | Cost: 2739.878 | Train/Valid Acc: 0.9720/0.9658
# epoch: 036 | Cost: 2594.496 | Train/Valid Acc: 0.9723/0.9672
# epoch: 037 | Cost: 2456.907 | Train/Valid Acc: 0.9735/0.9676
# epoch: 038 | Cost: 2326.714 | Train/Valid Acc: 0.9741/0.9704
# epoch: 039 | Cost: 2203.496 | Train/Valid Acc: 0.9746/0.9696
# epoch: 040 | Cost: 2086.901 | Train/Valid Acc: 0.9752/0.9702
# epoch: 041 | Cost: 1976.563 | Train/Valid Acc: 0.9759/0.9704
# epoch: 042 | Cost: 1872.147 | Train/Valid Acc: 0.9762/0.9696
# epoch: 043 | Cost: 1773.338 | Train/Valid Acc: 0.9767/0.9718
# epoch: 044 | Cost: 1679.839 | Train/Valid Acc: 0.9772/0.9708
# epoch: 045 | Cost: 1591.359 | Train/Valid Acc: 0.9777/0.9730
# epoch: 046 | Cost: 1507.639 | Train/Valid Acc: 0.9778/0.9726
# epoch: 047 | Cost: 1428.415 | Train/Valid Acc: 0.9777/0.9732
# epoch: 048 | Cost: 1353.448 | Train/Valid Acc: 0.9784/0.9740
# epoch: 049 | Cost: 1282.510 | Train/Valid Acc: 0.9788/0.9736
# epoch: 050 | Cost: 1215.385 | Train/Valid Acc: 0.9792/0.9742
# epoch: 051 | Cost: 1151.877 | Train/Valid Acc: 0.9792/0.9742
# epoch: 052 | Cost: 1091.785 | Train/Valid Acc: 0.9797/0.9756
# epoch: 053 | Cost: 1034.920 | Train/Valid Acc: 0.9799/0.9756
# epoch: 054 | Cost: 981.120 | Train/Valid Acc: 0.9800/0.9736
# epoch: 055 | Cost: 930.218 | Train/Valid Acc: 0.9797/0.9750
# epoch: 056 | Cost: 882.047 | Train/Valid Acc: 0.9810/0.9762
# epoch: 057 | Cost: 836.480 | Train/Valid Acc: 0.9806/0.9770
# epoch: 058 | Cost: 793.361 | Train/Valid Acc: 0.9812/0.9770
# epoch: 059 | Cost: 752.570 | Train/Valid Acc: 0.9806/0.9760
# epoch: 060 | Cost: 713.975 | Train/Valid Acc: 0.9816/0.9778
# epoch: 061 | Cost: 677.460 | Train/Valid Acc: 0.9817/0.9772
# epoch: 062 | Cost: 642.915 | Train/Valid Acc: 0.9822/0.9794
# epoch: 063 | Cost: 610.233 | Train/Valid Acc: 0.9823/0.9788
# epoch: 064 | Cost: 579.315 | Train/Valid Acc: 0.9823/0.9774
# epoch: 065 | Cost: 550.069 | Train/Valid Acc: 0.9826/0.9802
# epoch: 066 | Cost: 522.402 | Train/Valid Acc: 0.9825/0.9786
# epoch: 067 | Cost: 496.230 | Train/Valid Acc: 0.9815/0.9782
# epoch: 068 | Cost: 471.467 | Train/Valid Acc: 0.9817/0.9776
# epoch: 069 | Cost: 448.042 | Train/Valid Acc: 0.9830/0.9792
# epoch: 070 | Cost: 425.895 | Train/Valid Acc: 0.9820/0.9802
# epoch: 071 | Cost: 404.934 | Train/Valid Acc: 0.9832/0.9804
# epoch: 072 | Cost: 385.107 | Train/Valid Acc: 0.9831/0.9800
# epoch: 073 | Cost: 366.351 | Train/Valid Acc: 0.9829/0.9786
# epoch: 074 | Cost: 348.618 | Train/Valid Acc: 0.9823/0.9796
# epoch: 075 | Cost: 331.840 | Train/Valid Acc: 0.9822/0.9790
# epoch: 076 | Cost: 315.964 | Train/Valid Acc: 0.9832/0.9806
# epoch: 077 | Cost: 300.950 | Train/Valid Acc: 0.9836/0.9810
# epoch: 078 | Cost: 286.748 | Train/Valid Acc: 0.9835/0.9800
# epoch: 079 | Cost: 273.328 | Train/Valid Acc: 0.9823/0.9800
# epoch: 080 | Cost: 260.623 | Train/Valid Acc: 0.9828/0.9800
# epoch: 081 | Cost: 248.617 | Train/Valid Acc: 0.9815/0.9786
# epoch: 082 | Cost: 237.237 | Train/Valid Acc: 0.9834/0.9806
# epoch: 083 | Cost: 226.486 | Train/Valid Acc: 0.9842/0.9822
# epoch: 084 | Cost: 216.323 | Train/Valid Acc: 0.9838/0.9812
# epoch: 085 | Cost: 206.704 | Train/Valid Acc: 0.9840/0.9816
# epoch: 086 | Cost: 197.601 | Train/Valid Acc: 0.9838/0.9802
# epoch: 087 | Cost: 189.000 | Train/Valid Acc: 0.9826/0.9804
# epoch: 088 | Cost: 180.857 | Train/Valid Acc: 0.9835/0.9812
# epoch: 089 | Cost: 173.153 | Train/Valid Acc: 0.9841/0.9820
# epoch: 090 | Cost: 165.875 | Train/Valid Acc: 0.9842/0.9828
# epoch: 091 | Cost: 158.997 | Train/Valid Acc: 0.9841/0.9830
# epoch: 092 | Cost: 152.475 | Train/Valid Acc: 0.9841/0.9814
# epoch: 093 | Cost: 146.314 | Train/Valid Acc: 0.9849/0.9822
# epoch: 094 | Cost: 140.496 | Train/Valid Acc: 0.9842/0.9828
# epoch: 095 | Cost: 134.980 | Train/Valid Acc: 0.9839/0.9820
# epoch: 096 | Cost: 129.766 | Train/Valid Acc: 0.9839/0.9804
# epoch: 097 | Cost: 124.832 | Train/Valid Acc: 0.9837/0.9838
# epoch: 098 | Cost: 120.162 | Train/Valid Acc: 0.9845/0.9836
# epoch: 099 | Cost: 115.748 | Train/Valid Acc: 0.9835/0.9822
# epoch: 100 | Cost: 111.567 | Train/Valid Acc: 0.9837/0.9820
# epoch: 101 | Cost: 107.616 | Train/Valid Acc: 0.9833/0.9834
# epoch: 102 | Cost: 103.883 | Train/Valid Acc: 0.9841/0.9818
# epoch: 103 | Cost: 100.337 | Train/Valid Acc: 0.9845/0.9820
# epoch: 104 | Cost: 96.991 | Train/Valid Acc: 0.9838/0.9824
# epoch: 105 | Cost: 93.820 | Train/Valid Acc: 0.9845/0.9820
# epoch: 106 | Cost: 90.822 | Train/Valid Acc: 0.9844/0.9822
# epoch: 107 | Cost: 87.984 | Train/Valid Acc: 0.9835/0.9808
# epoch: 108 | Cost: 85.301 | Train/Valid Acc: 0.9844/0.9830
# epoch: 109 | Cost: 82.761 | Train/Valid Acc: 0.9835/0.9828
# epoch: 110 | Cost: 80.354 | Train/Valid Acc: 0.9840/0.9820
# epoch: 111 | Cost: 78.091 | Train/Valid Acc: 0.9842/0.9830
# epoch: 112 | Cost: 75.936 | Train/Valid Acc: 0.9848/0.9832
# epoch: 113 | Cost: 73.904 | Train/Valid Acc: 0.9845/0.9822
# epoch: 114 | Cost: 71.987 | Train/Valid Acc: 0.9840/0.9826
# epoch: 115 | Cost: 70.160 | Train/Valid Acc: 0.9847/0.9816
# epoch: 116 | Cost: 68.439 | Train/Valid Acc: 0.9837/0.9814
# epoch: 117 | Cost: 66.807 | Train/Valid Acc: 0.9843/0.9834
# epoch: 118 | Cost: 65.268 | Train/Valid Acc: 0.9833/0.9818
# epoch: 119 | Cost: 63.801 | Train/Valid Acc: 0.9848/0.9832
# epoch: 120 | Cost: 62.419 | Train/Valid Acc: 0.9844/0.9830
# epoch: 121 | Cost: 61.111 | Train/Valid Acc: 0.9848/0.9838
# epoch: 122 | Cost: 59.869 | Train/Valid Acc: 0.9851/0.9834
# epoch: 123 | Cost: 58.707 | Train/Valid Acc: 0.9835/0.9816
# epoch: 124 | Cost: 57.595 | Train/Valid Acc: 0.9842/0.9806
# epoch: 125 | Cost: 56.547 | Train/Valid Acc: 0.9837/0.9830
# epoch: 126 | Cost: 55.540 | Train/Valid Acc: 0.9848/0.9824
# epoch: 127 | Cost: 54.592 | Train/Valid Acc: 0.9847/0.9826
# epoch: 128 | Cost: 53.704 | Train/Valid Acc: 0.9849/0.9836
# epoch: 129 | Cost: 52.853 | Train/Valid Acc: 0.9849/0.9836
# epoch: 130 | Cost: 52.053 | Train/Valid Acc: 0.9848/0.9824
# epoch: 131 | Cost: 51.309 | Train/Valid Acc: 0.9826/0.9818
# epoch: 132 | Cost: 50.585 | Train/Valid Acc: 0.9829/0.9816
# epoch: 133 | Cost: 49.905 | Train/Valid Acc: 0.9842/0.9840
# epoch: 134 | Cost: 49.259 | Train/Valid Acc: 0.9851/0.9826
# epoch: 135 | Cost: 48.654 | Train/Valid Acc: 0.9843/0.9824
# epoch: 136 | Cost: 48.072 | Train/Valid Acc: 0.9851/0.9826
# epoch: 137 | Cost: 47.523 | Train/Valid Acc: 0.9850/0.9834
# epoch: 138 | Cost: 47.003 | Train/Valid Acc: 0.9853/0.9826
# epoch: 139 | Cost: 46.512 | Train/Valid Acc: 0.9846/0.9840
# epoch: 140 | Cost: 46.040 | Train/Valid Acc: 0.9854/0.9834
# epoch: 141 | Cost: 45.602 | Train/Valid Acc: 0.9850/0.9822
# epoch: 142 | Cost: 45.181 | Train/Valid Acc: 0.9851/0.9826
# epoch: 143 | Cost: 44.787 | Train/Valid Acc: 0.9848/0.9832
# epoch: 144 | Cost: 44.414 | Train/Valid Acc: 0.9855/0.9830
# epoch: 145 | Cost: 44.065 | Train/Valid Acc: 0.9854/0.9834
# epoch: 146 | Cost: 43.724 | Train/Valid Acc: 0.9851/0.9830
# epoch: 147 | Cost: 43.401 | Train/Valid Acc: 0.9857/0.9826
# epoch: 148 | Cost: 43.095 | Train/Valid Acc: 0.9857/0.9828
# epoch: 149 | Cost: 42.806 | Train/Valid Acc: 0.9855/0.9828
# epoch: 150 | Cost: 42.531 | Train/Valid Acc: 0.9857/0.9836
# epoch: 151 | Cost: 42.286 | Train/Valid Acc: 0.9851/0.9820
# epoch: 152 | Cost: 42.036 | Train/Valid Acc: 0.9851/0.9828
# epoch: 153 | Cost: 41.804 | Train/Valid Acc: 0.9852/0.9828
# epoch: 154 | Cost: 41.582 | Train/Valid Acc: 0.9854/0.9832
# epoch: 155 | Cost: 41.375 | Train/Valid Acc: 0.9852/0.9834
# epoch: 156 | Cost: 41.177 | Train/Valid Acc: 0.9850/0.9822
# epoch: 157 | Cost: 40.996 | Train/Valid Acc: 0.9830/0.9814
# epoch: 158 | Cost: 40.826 | Train/Valid Acc: 0.9841/0.9826
# epoch: 159 | Cost: 40.656 | Train/Valid Acc: 0.9851/0.9840
# epoch: 160 | Cost: 40.492 | Train/Valid Acc: 0.9851/0.9814
# epoch: 161 | Cost: 40.336 | Train/Valid Acc: 0.9861/0.9836
# epoch: 162 | Cost: 40.202 | Train/Valid Acc: 0.9856/0.9828
# epoch: 163 | Cost: 40.071 | Train/Valid Acc: 0.9845/0.9830
# epoch: 164 | Cost: 39.933 | Train/Valid Acc: 0.9857/0.9820
# epoch: 165 | Cost: 39.807 | Train/Valid Acc: 0.9854/0.9836
# epoch: 166 | Cost: 39.686 | Train/Valid Acc: 0.9852/0.9828
# epoch: 167 | Cost: 39.576 | Train/Valid Acc: 0.9853/0.9830
# epoch: 168 | Cost: 39.474 | Train/Valid Acc: 0.9852/0.9836
# epoch: 169 | Cost: 39.370 | Train/Valid Acc: 0.9860/0.9842
# epoch: 170 | Cost: 39.276 | Train/Valid Acc: 0.9847/0.9826
# epoch: 171 | Cost: 39.182 | Train/Valid Acc: 0.9854/0.9832
# epoch: 172 | Cost: 39.105 | Train/Valid Acc: 0.9853/0.9836
# epoch: 173 | Cost: 39.022 | Train/Valid Acc: 0.9854/0.9820
# epoch: 174 | Cost: 38.941 | Train/Valid Acc: 0.9856/0.9838
# epoch: 175 | Cost: 38.867 | Train/Valid Acc: 0.9863/0.9838
# epoch: 176 | Cost: 38.809 | Train/Valid Acc: 0.9858/0.9834
# epoch: 177 | Cost: 38.741 | Train/Valid Acc: 0.9855/0.9834
# epoch: 178 | Cost: 38.682 | Train/Valid Acc: 0.9854/0.9830
# epoch: 179 | Cost: 38.608 | Train/Valid Acc: 0.9863/0.9832
# epoch: 180 | Cost: 38.559 | Train/Valid Acc: 0.9859/0.9846
# epoch: 181 | Cost: 38.522 | Train/Valid Acc: 0.9852/0.9826
# epoch: 182 | Cost: 38.461 | Train/Valid Acc: 0.9860/0.9830
# epoch: 183 | Cost: 38.409 | Train/Valid Acc: 0.9857/0.9840
# epoch: 184 | Cost: 38.352 | Train/Valid Acc: 0.9860/0.9844
# epoch: 185 | Cost: 38.305 | Train/Valid Acc: 0.9858/0.9824
# epoch: 186 | Cost: 38.266 | Train/Valid Acc: 0.9858/0.9828
# epoch: 187 | Cost: 38.233 | Train/Valid Acc: 0.9847/0.9820
# epoch: 188 | Cost: 38.188 | Train/Valid Acc: 0.9855/0.9834
# epoch: 189 | Cost: 38.159 | Train/Valid Acc: 0.9854/0.9828
# epoch: 190 | Cost: 38.120 | Train/Valid Acc: 0.9860/0.9822
# epoch: 191 | Cost: 38.089 | Train/Valid Acc: 0.9857/0.9834
# epoch: 192 | Cost: 38.055 | Train/Valid Acc: 0.9858/0.9826
# epoch: 193 | Cost: 38.032 | Train/Valid Acc: 0.9851/0.9838
# epoch: 194 | Cost: 37.997 | Train/Valid Acc: 0.9861/0.9824
# epoch: 195 | Cost: 37.975 | Train/Valid Acc: 0.9855/0.9824
# epoch: 196 | Cost: 37.943 | Train/Valid Acc: 0.9861/0.9834
# epoch: 197 | Cost: 37.917 | Train/Valid Acc: 0.9860/0.9828
# epoch: 198 | Cost: 37.899 | Train/Valid Acc: 0.9836/0.9828
# epoch: 199 | Cost: 37.875 | Train/Valid Acc: 0.9858/0.9822

# %%
nn.save_weights()

# %%
np.argmax(nn.eval_['valid_acc'])
# Out:
# 180

# %%
plt.plot(range(nn.epochs), nn.eval_['cost'])
plt.ylabel('Cost')
plt.xlabel('Epochs')
plt.show()

# %%
plt.plot(range(nn.epochs), nn.eval_['train_acc'], label='Training')
plt.plot(range(nn.epochs), nn.eval_['valid_acc'], label='Validation', linestyle='--')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.show()

# %%
y_test_pred = nn.predict(x_test)
acc = np.sum(y_test == y_test_pred).astype(np.float32) / x_test.shape[0]
print(f"Test accuracy: {acc:.4f}")
# Out:
# Test accuracy: 0.9775
